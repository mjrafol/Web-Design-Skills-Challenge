# %%
import pandas as pd
from decimal import Decimal
# Out:
# C:\Users\mjrafol\Anaconda3\envs\PythonData\lib\site-packages\numpy\__init__.py:140: UserWarning: mkl-service package failed to import, therefore Intel(R) MKL initialization ensuring its correct out-of-the box operation under condition when Gnu OpenMP had already been loaded by Python process is not assured. Please install mkl-service package, see http://github.com/IntelPython/mkl-service
#   from . import _distributor_init
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14844\907405597.py in <module>
# ----> 1 import pandas as pd
#       2 from decimal import Decimal
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\__init__.py in <module>
#      15 if missing_dependencies:
#      16     raise ImportError(
# ---> 17         "Unable to import required dependencies:\n" + "\n".join(missing_dependencies)
#      18     )
# ...

# %%
# Read the CSV file
df = pd.read_csv("cities.csv")

# %%
# Copy the df before making any changes (dropping records with NA)
df2 = df
df3 = df2.dropna(how = "any")

# View the new df
df3
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         suntar  62.1444  117.6319     33.26      64.0       100.0
# 1         atuona  -9.8000 -139.0333     79.50      77.0        76.0
# 2        talnakh  69.4865   88.3972     -0.80      95.0        56.0
# 3       sao joao  -8.8756  -36.3667     68.23      95.0        86.0
# 4        ushuaia -54.8000  -68.3000     42.46      75.0        40.0
# ..           ...      ...       ...       ...       ...         ...
# 629      ha tinh  18.3333  105.9000     85.89      65.0        13.0
# 630  nortelandia -14.4547  -56.8028     73.62      88.0       100.0
# 631    geraldton -28.7667  114.6000     77.41      38.0         2.0
# 633        buala  -8.1450  159.5921     85.69      68.0        24.0
# 634    taoudenni  22.6783   -3.9836     75.54      18.0        11.0
#
#      Wind Speed Country          Date
# 0          4.00      RU  1.650764e+09
# 1         16.64      PF  1.650764e+09
# ...

# %%
# Check the df datatypes
df3.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date          float64
# dtype: object

# %%
df4 = df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14844\3719526015.py in <module>
# ----> 1 df4 = df3
#
# NameError: name 'df3' is not defined

# %%
df4["Lat"] = df3["Lat"].astype("float64").round(2)
df4["Lng"] = df3["Lng"].astype("float64").round(2)
df4["Date"]= df3["Date"].apply(pd.to_datetime)
# df3["Date"]=Decimal(df3["Date"])
# df3['Date'] = pd.to_datetime(df3['Date'], format='%Y%m%d%H%M%S')
# df3["Date"] = df3["Date"].astype("datetime64[ns]")
df4
# Out:
# C:\Users\mjrafol\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mjrafol\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mjrafol\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df4.to_html('cities.html')
